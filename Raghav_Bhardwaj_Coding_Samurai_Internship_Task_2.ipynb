# %%
import pandas as pd

#Data Collection
# Loading CSV files into DataFrames
calendar_df = pd.read_csv('calendar.csv')
listings_df = pd.read_csv('listings.csv')
reviews_df = pd.read_csv('reviews.csv')

# %%
# Displaying first few rows of each DataFrame
print("Calendar Data:")
print(calendar_df.head())
print("\nListings Data:")
print(listings_df.head())
print("\nReviews Data:")
print(reviews_df.head())


# Checking data types of columns
print("\nData Types:")
print(calendar_df.dtypes)
print(listings_df.dtypes)
print(reviews_df.dtypes)
# Out:
# Calendar Data:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN
#
# Listings Data:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# ...

# %%
# Checking for missing values
print("Missing Values:")
print(calendar_df.isnull().sum())
print(listings_df.isnull().sum())
print(reviews_df.isnull().sum())

# Handling missing values (dropping null values)
reviews_df.dropna(inplace=True)
# Out:
# Missing Values:
# listing_id         0
# date               0
# available          0
# price         459028
# dtype: int64
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   627
# Length: 92, dtype: int64
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         18
# dtype: int64

# %%
# Basic Statistics

# Visualizing distribution of neighborhoods
plt.figure(figsize=(10, 6))
property_type_counts.plot(kind='bar', xlabel='review_scores_value', ylabel='Count', title='Distribution of review_scores_value', rot=45)
plt.tight_layout()  # Adjust spacing
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example visualization (Price distribution)
plt.figure(figsize=(10, 6))
sns.histplot(calendar_df['price'], bins=30, kde=True)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution of Airbnb Listings')
plt.show()

# %%
# Example correlation analysis
correlation_matrix = listings_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Airbnb Listing Features')
plt.show()
# Out:
# <ipython-input-36-800e68d4ae2e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = listings_df.corr()

# %%
# Example data insights
average_rating = listings_df['review_scores_rating'].mean()

print("Data Insights:")
print("- The average rating of Airbnb listings is:", average_rating)
# Out:
# Data Insights:
# - The average rating of Airbnb listings is: 94.53926206244087
